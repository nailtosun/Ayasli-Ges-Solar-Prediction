# %%
from __future__ import print_function
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import keras
from keras import metrics
from keras import regularizers
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Activation
from keras.layers import Conv2D, MaxPooling2D
from keras.optimizers import Adam, RMSprop
from keras.callbacks import TensorBoard, EarlyStopping, ModelCheckpoint
from keras.utils import plot_model
from keras.models import load_model
data=pd.read_csv('july-dataset4.csv')
humidity = data['Humidity']
Epoch_Time = data['Epoch_Time']
Cloud_Cover = data['Cloud_Cover']
Dew_Point = data['Dew_Point']
Humidity = data['Humidity']
Pressure = data['Pressure']
Temperature = data['Temperature']
Wind_Speed = data['Wind_Speed']
Visibility = data['Visibility']
Hour_map = data['Hour_map']

# %%
def spliting_data(df, training_percent = 0.7, validation_percent = 0.15, testing_percent = 0.15, seed = None):
    np.random.seed(seed)
    total_size = training_percent + validation_percent + testing_percent
    if total_size != 1:
        raise ValueError('total size must be 1 not {}'.format(total_size))
    training_end = int(training_percent * len(df))
    validate_end = int(validation_percent * len(df)) + training_end
    perm = np.random.permutation(df.index) # randomize indexs
    training = perm[:training_end]
    validate = perm[training_end:validate_end]
    testing = perm[validate_end:]
    return training, validate, testing
def norm_stats(df1, df2):
    dfs = df1.append(df2)
    minimum = np.min(dfs)
    maximum = np.max(dfs)
    mu = np.mean(dfs)
    sigma = np.std(dfs)
    return (minimum, maximum, mu, sigma)

def z_score(col, stats):
    m, M, mu, s = stats
    df2 = pd.DataFrame()
    for c in col.columns:
        df2[c] = (col[c]-mu[c])/s[c]
    return df2
def basic_model_3(x_size, y_size):
    t_model = Sequential()
    t_model.add(Dense(80, activation="tanh", kernel_initializer='normal', input_shape=(x_size,)))
    t_model.add(Dropout(0.2))
    t_model.add(Dense(120, activation="relu", kernel_initializer='normal', 
        kernel_regularizer=regularizers.l1(0.01), bias_regularizer=regularizers.l1(0.01)))
    t_model.add(Dropout(0.1))
    t_model.add(Dense(20, activation="relu", kernel_initializer='normal', 
        kernel_regularizer=regularizers.l1_l2(0.01), bias_regularizer=regularizers.l1_l2(0.01)))
    t_model.add(Dropout(0.1))
    t_model.add(Dense(10, activation="relu", kernel_initializer='normal'))
    t_model.add(Dropout(0.0))
    t_model.add(Dense(y_size))
    t_model.compile(
        loss='mean_squared_error',
        optimizer='nadam',
        metrics=[metrics.mae])
    return(t_model)
def plot_hist(h, xsize=6, ysize=10):
    # Prepare plotting
    fig_size = plt.rcParams["figure.figsize"]
    plt.rcParams["figure.figsize"] = [xsize, ysize]
    fig, axes = plt.subplots(nrows=4, ncols=4, sharex=True)
    
    # summarize history for MAE
    plt.subplot(211)
    plt.plot(h['mean_absolute_error'])
    plt.plot(h['val_mean_absolute_error'])
    plt.title('Training vs Validation MAE')
    plt.ylabel('MAE')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')
    
    # summarize history for loss
    plt.subplot(212)
    plt.plot(h['loss'])
    plt.plot(h['val_loss'])
    plt.title('Training vs Validation Loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Validation'], loc='upper left')
    
    # Plot it all in IPython (non-interactive)
    plt.draw()
    plt.show()

    return

# %%
training,validate,testing = spliting_data(data)
df = pd.DataFrame(data, columns=[
        'Epoch_Time','Cloud_Cover','Dew_Point',
        'Humidity','Pressure','Temperature','Wind_Speed','Visibility',
        'Power_Output'])
label_col = 'Power_Output'
y_train = df.loc[training, [label_col]]
x_train = df.loc[training, :].drop(label_col, axis=1)
y_valid = df.loc[validate, [label_col]]
x_valid = df.loc[validate, :].drop(label_col, axis=1)

print('Size of training set: ', len(x_train))
print('Size of validation set: ', len(x_valid))
print('Size of test set: ', len(testing), '(not converted)')
stats = norm_stats(x_train, x_valid)
arr_x_train = np.array(z_score(x_train, stats))
arr_y_train = np.array(y_train)
arr_x_valid = np.array(z_score(x_valid, stats))
arr_y_valid = np.array(y_valid)

print('Training shape:', arr_x_train.shape)
print('Training samples: ', arr_x_train.shape[0])
print('Validation samples: ', arr_x_valid.shape[0])

# %%
model = basic_model_3(arr_x_train.shape[1], arr_y_train.shape[1])
model.summary()

# %%
epochs = 500
batch_size = 32

print('Epochs: ', epochs)
print('Batch size: ', batch_size)
keras_callbacks = [
    # ModelCheckpoint('/tmp/keras_checkpoints/model.{epoch:02d}-{val_loss:.2f}.hdf5', monitor='val_loss', save_best_only=True, verbose=2)
    # ModelCheckpoint('/tmp/keras_checkpoints/model.{epoch:02d}.hdf5', monitor='val_loss', save_best_only=True, verbose=0)
    # TensorBoard(log_dir='/tmp/keras_logs/model_3', histogram_freq=0, write_graph=True, write_images=True, embeddings_freq=0, embeddings_layer_names=None, embeddings_metadata=None),
    EarlyStopping(monitor='val_mean_absolute_error', patience=20, verbose=0)
]
history = model.fit(arr_x_train, arr_y_train,
    batch_size=batch_size,
    epochs=epochs,
    shuffle=True,
    verbose=2, # Change it to 2, if wished to observe execution
    validation_data=(arr_x_valid, arr_y_valid),
    callbacks=keras_callbacks)
# Out:
# Epochs:  500
# Batch size:  32
# Train on 6249 samples, validate on 1339 samples
# Epoch 1/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 2/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 3/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 4/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 5/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 6/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 7/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 8/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 9/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 10/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 11/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 12/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 13/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 14/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 15/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 16/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 17/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 18/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 19/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 20/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 21/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 22/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 23/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 24/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 25/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 26/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 27/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 28/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 29/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 30/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 31/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 32/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 33/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 34/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 35/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 36/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 37/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 38/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 39/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 40/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 41/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 42/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 43/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 44/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 45/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 46/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 47/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 48/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 49/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 50/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 51/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 52/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 53/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 54/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 55/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 56/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 57/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 58/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 59/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 60/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 61/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 62/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 63/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 64/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 65/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 66/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 67/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 68/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 69/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 70/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 71/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 72/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 73/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 74/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 75/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 76/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 77/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 78/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 79/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 80/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 81/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 82/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 83/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 84/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 85/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 86/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 87/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 88/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 89/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 90/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 91/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 92/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 93/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 94/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 95/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 96/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 97/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 98/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 99/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 100/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 101/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 102/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 103/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 104/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 105/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 106/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 107/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 108/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 109/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 110/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 111/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 112/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 113/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 114/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 115/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 116/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 117/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 118/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 119/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 120/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 121/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 122/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 123/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 124/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 125/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 126/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 127/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 128/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 129/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 130/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 131/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 132/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 133/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 134/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 135/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 136/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 137/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 138/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 139/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 140/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 141/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 142/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 143/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 144/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 145/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 146/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 147/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 148/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 149/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 150/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 151/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 152/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 153/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 154/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 155/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 156/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 157/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 158/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 159/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 160/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 161/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 162/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 163/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 164/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 165/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 166/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 167/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 168/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 169/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 170/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 171/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 172/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 173/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 174/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 175/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 176/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 177/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 178/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 179/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 180/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 181/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 182/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 183/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 184/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 185/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 186/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 187/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 188/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 189/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 190/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 191/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 192/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 193/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 194/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 195/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 196/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 197/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 198/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 199/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 200/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 201/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 202/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 203/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 204/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 205/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 206/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 207/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 208/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 209/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 210/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 211/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 212/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 213/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 214/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 215/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 216/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 217/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 218/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 219/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 220/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 221/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 222/500
#  - 1s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 223/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 224/500
#  - 1s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 225/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 226/500
#  - 1s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 227/500
#  - 1s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 228/500
#  - 1s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 229/500
#  - 1s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 230/500
#  - 1s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 231/500
#  - 1s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 232/500
#  - 1s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 233/500
#  - 1s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 234/500
#  - 1s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 235/500
#  - 1s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 236/500
#  - 1s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 237/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 238/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 239/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 240/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 241/500
#  - 0s - loss: nan - mean_absolute_error: nan - val_loss: nan - val_mean_absolute_error: nan
# Epoch 242/500

# %%
plot_hist(history.history, xsize=8, ysize=12)

# %%
train_score = model.evaluate(arr_x_train, arr_y_train, verbose=2)
valid_score = model.evaluate(arr_x_valid, arr_y_valid, verbose=2)

print('Train MAE: ', round(train_score[1], 4), ', Train Loss: ', round(train_score[0], 4)) 
print('Val MAE: ', round(valid_score[1], 4), ', Val Loss: ', round(valid_score[0], 4))
# Out:
# Train MAE:  2219.3467 , Train Loss:  16353089.9171
# Val MAE:  2386.866 , Val Loss:  19417575.997

# %%
dataForTest1 = np.array([1530400800,0.35,48.85,0.65,1009.48,60.51,0.00,6.22])

# %%
data = pd.read_csv('data.csv')
data = data.drop('Power_Output',1)

# %%
data
# Out:
#      Epoch_Time  Cloud_Cover  Dew_Point  Humidity  Pressure  Temperature  \
# 0    1530392400         0.36      49.98      0.63   1009.71        62.90
# 1    1530392700         0.36      49.99      0.63   1009.70        62.75
# 2    1530393000         0.36      49.99      0.63   1009.69        62.60
# 3    1530393300         0.36      50.00      0.64   1009.68        62.45
# 4    1530393600         0.36      50.00      0.64   1009.68        62.30
# 5    1530393900         0.36      50.00      0.64   1009.67        62.15
# 6    1530394200         0.35      50.00      0.65   1009.66        62.00
# 7    1530394500         0.35      50.00      0.65   1009.65        61.85
# 8    1530394800         0.35      50.00      0.65   1009.65        61.70
# 9    1530395100         0.35      50.00      0.66   1009.64        61.55
# 10   1530395400         0.35      49.99      0.66   1009.63        61.41
# 11   1530395700         0.35      49.99      0.66   1009.63        61.26
# 12   1530396000         0.35      49.99      0.67   1009.62        61.11
# 13   1530396300         0.35      49.84      0.66   1009.61        61.11
# 14   1530396600         0.35      49.70      0.66   1009.60        61.11
# 15   1530396900         0.35      49.55      0.66   1009.59        61.11
# 16   1530397200         0.35      49.40      0.65   1009.58        61.11
# 17   1530397500         0.35      49.26      0.65   1009.57        61.11
# 18   1530397800         0.35      49.11      0.65   1009.56        61.11
# 19   1530398100         0.35      48.96      0.64   1009.55        61.11
# 20   1530398400         0.35      48.81      0.64   1009.54        61.11
# 21   1530398700         0.35      48.66      0.64   1009.53        61.11
# 22   1530399000         0.35      48.51      0.63   1009.52        61.11
# 23   1530399300         0.35      48.35      0.63   1009.51        61.11
# 24   1530399600         0.35      48.20      0.63   1009.50        61.11
# 25   1530399900         0.35      48.37      0.63   1009.50        60.96
# 26   1530400200         0.35      48.53      0.64   1009.49        60.81
# 27   1530400500         0.35      48.69      0.65   1009.49        60.66
# 28   1530400800         0.35      48.85      0.65   1009.48        60.51
# 29   1530401100         0.35      49.00      0.66   1009.48        60.36
# ..          ...          ...        ...       ...       ...          ...
# 258  1530469800         0.19      53.63      0.53   1009.37        71.90
# 259  1530470100         0.19      53.63      0.53   1009.39        71.61
# 260  1530470400         0.19      53.63      0.54   1009.42        71.31
# 261  1530470700         0.19      53.62      0.54   1009.44        71.01
# 262  1530471000         0.19      53.61      0.55   1009.46        70.71
# 263  1530471300         0.19      53.60      0.55   1009.48        70.41
# 264  1530471600         0.19      53.58      0.56   1009.50        70.11
# 265  1530471900         0.20      53.77      0.57   1009.51        69.81
# 266  1530472200         0.22      53.96      0.58   1009.53        69.51
# 267  1530472500         0.23      54.13      0.59   1009.54        69.21
# 268  1530472800         0.25      54.30      0.60   1009.55        68.91
# 269  1530473100         0.26      54.46      0.61   1009.56        68.61
# 270  1530473400         0.28      54.62      0.62   1009.57        68.31
# 271  1530473700         0.29      54.76      0.63   1009.58        68.01
# 272  1530474000         0.31      54.90      0.64   1009.59        67.71
# 273  1530474300         0.32      55.04      0.65   1009.60        67.41
# 274  1530474600         0.34      55.16      0.66   1009.61        67.11
# 275  1530474900         0.35      55.28      0.66   1009.63        66.81
# 276  1530475200         0.36      55.40      0.67   1009.64        66.51
# 277  1530475500         0.36      55.40      0.67   1009.64        66.51
# 278  1530475800         0.36      55.40      0.67   1009.64        66.51
# 279  1530476100         0.36      55.40      0.67   1009.64        66.51
# 280  1530476400         0.36      55.40      0.67   1009.64        66.51
# 281  1530476700         0.36      55.40      0.67   1009.64        66.51
# 282  1530477000         0.36      55.40      0.67   1009.64        66.51
# 283  1530477300         0.36      55.40      0.67   1009.64        66.51
# 284  1530477600         0.36      55.40      0.67   1009.64        66.51
# 285  1530477900         0.36      55.40      0.67   1009.64        66.51
# 286  1530478200         0.36      55.40      0.67   1009.64        66.51
# 287  1530478500         0.35      55.40      0.67   1009.64        66.51
#
#      Wind_Speed  Visibility  Hour_map
# 0          4.02        6.22    0.0000
# 1          3.90        6.22    0.0035
# 2          3.79        6.22    0.0069
# 3          3.69        6.22    0.0104
# 4          3.60        6.22    0.0139
# 5          3.53        6.22    0.0174
# 6          3.46        6.22    0.0208
# 7          3.41        6.22    0.0243
# 8          3.37        6.22    0.0278
# 9          3.35        6.22    0.0313
# 10         3.34        6.22    0.0347
# 11         3.34        6.22    0.0382
# 12         3.36        6.22    0.0417
# 13         3.08        6.22    0.0451
# 14         2.80        6.22    0.0486
# 15         2.52        6.22    0.0521
# 16         2.24        6.22    0.0556
# 17         1.96        6.22    0.0590
# 18         1.68        6.22    0.0625
# 19         1.40        6.22    0.0660
# 20         1.12        6.22    0.0694
# 21         0.84        6.22    0.0729
# 22         0.56        6.22    0.0764
# 23         0.28        6.22    0.0799
# 24         0.00        6.22    0.0833
# 25         0.00        6.22    0.0868
# 26         0.00        6.22    0.0903
# 27         0.00        6.22    0.0938
# 28         0.00        6.22    0.0972
# 29         0.00        6.22    0.1007
# ..          ...         ...       ...
# 258        5.81        6.22    0.8958
# 259        5.62        6.22    0.8993
# 260        5.43        6.22    0.9028
# 261        5.25        6.22    0.9063
# 262        5.06        6.22    0.9097
# 263        4.87        6.22    0.9132
# 264        4.69        6.22    0.9167
# 265        4.84        6.22    0.9201
# 266        5.01        6.22    0.9236
# 267        5.18        6.22    0.9271
# 268        5.36        6.22    0.9306
# 269        5.54        6.22    0.9340
# 270        5.73        6.22    0.9375
# 271        5.92        6.22    0.9410
# 272        6.12        6.22    0.9444
# 273        6.32        6.22    0.9479
# 274        6.52        6.22    0.9514
# 275        6.72        6.22    0.9549
# 276        6.93        6.22    0.9583
# 277        6.93        6.22    0.9618
# 278        6.93        6.22    0.9653
# 279        6.93        6.22    0.9688
# 280        6.93        6.22    0.9722
# 281        6.93        6.22    0.9757
# 282        6.93        6.22    0.9792
# 283        6.93        6.22    0.9826
# 284        6.93        6.22    0.9861
# 285        6.93        6.22    0.9896
# 286        6.93        6.22    0.9931
# 287        6.93        6.22    0.9965
#
# [288 rows x 9 columns]

# %%
model.predict(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-cf4d2fb4f85a> in <module>()
# ----> 1 model.predict(data)
#
# ~\Anaconda3\lib\site-packages\keras\models.py in predict(self, x, batch_size, verbose, steps)
#    1062             self.build()
#    1063         return self.model.predict(x, batch_size=batch_size, verbose=verbose,
# -> 1064                                   steps=steps)
#    1065
#    1066     def predict_on_batch(self, x):
#
# ~\Anaconda3\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps)
#    1815         x = _standardize_input_data(x, self._feed_input_names,
#    1816                                     self._feed_input_shapes,
# -> 1817                                     check_batch_axis=False)
#    1818         if self.stateful:
#    1819             if x[0].shape[0] > batch_size and x[0].shape[0] % batch_size != 0:
#
# ~\Anaconda3\lib\site-packages\keras\engine\training.py in _standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     121                             ': expected ' + names[i] + ' to have shape ' +
#     122                             str(shape) + ' but got array with shape ' +
# --> 123                             str(data_shape))
#     124     return data
#     125
#
# ValueError: Error when checking : expected dense_6_input to have shape (8,) but got array with shape (10,)
